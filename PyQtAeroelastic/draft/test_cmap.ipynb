# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1, 10, 10)
y = np.linspace(1, 10, 10)
X, Y = np.meshgrid(x, y)
Z = X + Y

# %%
fig = plt.figure()
axes = fig.add_subplot(111)
axes.contourf(X, Y, Z)
fig.show()
# Out:
# C:\Users\bcynuaa\AppData\Local\Temp\ipykernel_23644\3337309754.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
